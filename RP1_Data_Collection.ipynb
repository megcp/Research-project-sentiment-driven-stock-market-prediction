# %% [markdown]
# <a href="https://colab.research.google.com/github/megcp/Research-project-sentiment-driven-stock-market-prediction/blob/main/RP1_Data_Collection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import csv
import requests

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Collecting Apple Headlines

# %% [markdown]
# https://www.alphavantage.co/documentation/

# %%
# key obtained from Apha vantage website
key = 'NE5GFXD4RLX6OI21'

# %%
url = 'https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=AAPL&apikey={key}&time_from=20230605T0000&time_to=20240605T2359&limit=1000'
r = requests.get(url)
data1 = r.json()

data1
# Out:
# {'items': '684',
#  'sentiment_score_definition': 'x <= -0.35: Bearish; -0.35 < x <= -0.15: Somewhat-Bearish; -0.15 < x < 0.15: Neutral; 0.15 <= x < 0.35: Somewhat_Bullish; x >= 0.35: Bullish',
#  'relevance_score_definition': '0 < x <= 1, with a higher score indicating higher relevance.',
#  'feed': [{'title': 'Panasonic Announces New LUMIX GH7 Micro Four-Thirds Mirrorless Camera',
#    'url': 'https://www.benzinga.com/pressreleases/24/06/n39195121/panasonic-announces-new-lumix-gh7-micro-four-thirds-mirrorless-camera',
#    'time_published': '20240605T210000',
#    'authors': ['PRNewswire'],
#    'summary': 'NEWARK, N.J., June 5, 2024 /PRNewswire/ -- Panasonic is proud to introduce the new LUMIX GH7 - the latest flagship model of the Micro Four Thirds mirrorless LUMIX G Series.',
#    'banner_image': 'https://www.benzinga.com/next-assets/images/schema-image-default.png',
#    'source': 'Benzinga',
#    'category_within_source': 'General',
#    'source_domain': 'www.benzinga.com',
# ...

# %%
articles_data1 = []
for article in data1['feed']:
    article_info = {
        'Title': article['title'],
        'Time Published': pd.to_datetime(article['time_published'], format='%Y%m%dT%H%M%S'),
        'Summary': article['summary'],
        'Source': article['source'],
        'Topic': ', '.join(topic['topic'] for topic in article['topics']),
        'Sentiment Score': article['overall_sentiment_score'],
        'Sentiment Label': article['overall_sentiment_label'],
    }
    articles_data1.append(article_info)

df1 = pd.DataFrame(articles_data1)

# %%
df1
# Out:
#                                                  Title      Time Published  \
# 0    Panasonic Announces New LUMIX GH7 Micro Four-T... 2024-06-05 21:00:00
# 1    Nasdaq, S&P 500 Run To New Highs; 11 Stocks In... 2024-06-05 20:48:00
# 2    Nvidia Crosses $3T Market Cap: AI Darling Join... 2024-06-05 20:38:07
# 3    S&P 500, Nasdaq 100 Jointly Hit All-Time Highs... 2024-06-05 20:18:04
# 4    Nvidia Stock Hits $3 Trillion Market Value, Jo... 2024-06-05 19:22:00
# ..                                                 ...                 ...
# 679  'It's An Obvious Move:' Elon Musk Nudges Warre... 2024-05-06 07:36:27
# 680  Investor Optimism Improves Slightly Following ... 2024-05-06 03:22:50
# 681  Apple Should Turn This Device Into Laptop Repl... 2024-05-06 03:03:30
# 682  Highlights From Warren Buffett's Berkshire Hat... 2024-05-05 20:58:08
# 683  Apple Has a Problem -- and Investors Should Lo... 2024-05-05 18:00:00
#
#                                                Summary  \
# ...

# %%
url = 'https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=AAPL&apikey={key}&time_from=20230605T0000&time_to=20240505T1759&limit=1000'
r = requests.get(url)
data2 = r.json()

articles_data2 = []
for article in data2['feed']:
    article_info = {
        'Title': article['title'],
        'Time Published': pd.to_datetime(article['time_published'], format='%Y%m%dT%H%M%S'),
        'Summary': article['summary'],
        'Source': article['source'],
        'Topic': ', '.join(topic['topic'] for topic in article['topics']),
        'Sentiment Score': article['overall_sentiment_score'],
        'Sentiment Label': article['overall_sentiment_label'],
    }
    articles_data2.append(article_info)

df2 = pd.DataFrame(articles_data2)

# %%
df2
# Out:
#                                                  Title      Time Published  \
# 0    3 High-Yield Artificial Intelligence Plays Pay... 2024-05-05 16:01:00
# 1    Read This Before You Buy the Invesco QQQ Trust... 2024-05-05 14:34:00
# 2              Apple's Fiscal Q2: EPS Up, Revenue Down 2024-05-05 14:20:27
# 3              Should Stubborn Bears Expect More Pain? 2024-05-05 13:35:06
# 4    Some of the Biggest Billionaires in the World ... 2024-05-05 11:05:00
# ..                                                 ...                 ...
# 678  Natural Language Processing Market size is set... 2024-04-04 19:16:00
# 679  Taiwan's semiconductor industry resumes operat... 2024-04-04 18:41:32
# 680  Taiwan's semiconductor industry resumes operat... 2024-04-04 18:41:32
# 681  Market Clubhouse Morning Memo - April 4th, 202... 2024-04-04 17:35:24
# 682  Nvidia, Alphabet lead market cap surge in Marc... 2024-04-04 16:19:45
#
# ...

# %%
url = 'https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=AAPL&apikey={key}&time_from=20230605T0000&time_to=20240404T1518&limit=1000'
r = requests.get(url)
data3 = r.json()

articles_data3 = []
for article in data3['feed']:
    article_info = {
        'Title': article['title'],
        'Time Published': pd.to_datetime(article['time_published'], format='%Y%m%dT%H%M%S'),
        'Summary': article['summary'],
        'Source': article['source'],
        'Topic': ', '.join(topic['topic'] for topic in article['topics']),
        'Sentiment Score': article['overall_sentiment_score'],
        'Sentiment Label': article['overall_sentiment_label'],
    }
    articles_data3.append(article_info)

# Create DataFrame
df3 = pd.DataFrame(articles_data3)

# %%
df3
# Out:
#                                                  Title      Time Published  \
# 0    ROKU Collaborates With NBA to Introduce Latest... 2024-04-04 13:21:00
# 1                Has Apple Vision Pro Already Flopped? 2024-04-04 12:30:00
# 2    As Apple Tosses Away EV Plans, Chinese Smartph... 2024-04-04 11:00:16
# 3    iPhone 16 Rumors Roundup: Everything We Know A... 2024-04-04 10:45:26
# 4    Should Schwab Fundamental U.S. Large Company I... 2024-04-04 10:20:04
# ..                                                 ...                 ...
# 681  'I Sense Serious Apple Panic': Jim Cramer Says... 2024-03-05 12:30:22
# 682  Corporate giants have huge bond holdings, and ... 2024-03-05 12:15:00
# 683  How Morgan Stanley's bearish strategist may be... 2024-03-05 11:57:00
# 684    2 Natixis Mutual Funds to Buy for Steady Growth 2024-03-05 11:39:00
# 685  Blackstone's giant real estate arm wants to do... 2024-03-05 11:35:08
#
# ...

# %%
url = 'https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=AAPL&apikey={key}&time_from=20230605T0000&time_to=20240305T1134&limit=1000'
r = requests.get(url)
data4 = r.json()

articles_data4 = []
for article in data4['feed']:
    article_info = {
        'Title': article['title'],
        'Time Published': pd.to_datetime(article['time_published'], format='%Y%m%dT%H%M%S'),
        'Summary': article['summary'],
        'Source': article['source'],
        'Topic': ', '.join(topic['topic'] for topic in article['topics']),
        'Sentiment Score': article['overall_sentiment_score'],
        'Sentiment Label': article['overall_sentiment_label'],
    }
    articles_data4.append(article_info)


df4 = pd.DataFrame(articles_data4)

# %%
df4
# Out:
#                                                  Title      Time Published  \
# 0    1 Mind-Blowing Quote That Shows Why This Artif... 2024-03-05 11:30:00
# 1    Should TCW Transform 500 ETF  ( VOTE )  Be on ... 2024-03-05 11:20:07
# 2    Is SoFi Select 500 ETF  ( SFY )  a Strong ETF ... 2024-03-05 11:20:07
# 3    Should Schwab 1000 Index ETF  ( SCHK )  Be on ... 2024-03-05 11:20:06
# 4    Is Schwab Fundamental U.S. Large Company Index... 2024-03-05 11:20:06
# ..                                                 ...                 ...
# 681  Warren Buffett Has Bought More of This Stock T... 2024-02-05 12:25:00
# 682  Apple's Phil Schiller Warns Of Privacy Threats... 2024-02-05 11:46:38
# 683  Fate of the Mag 7 depends on their ability to ... 2024-02-05 11:46:00
# 684  Zacks Investment Ideas feature highlights: Mic... 2024-02-05 11:00:00
# 685  Microsoft, Meta Platforms, Amazon, Apple, Alph... 2024-02-05 11:00:00
#
# ...

# %%
url = 'https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=AAPL&apikey={key}&time_from=20230605T0000&time_to=20240205T1059&limit=1000'
r = requests.get(url)
data5 = r.json()

articles_data5 = []
for article in data5['feed']:
    article_info = {
        'Title': article['title'],
        'Time Published': pd.to_datetime(article['time_published'], format='%Y%m%dT%H%M%S'),
        'Summary': article['summary'],
        'Source': article['source'],
        'Topic': ', '.join(topic['topic'] for topic in article['topics']),
        'Sentiment Score': article['overall_sentiment_score'],
        'Sentiment Label': article['overall_sentiment_label'],
    }
    articles_data5.append(article_info)

df5 = pd.DataFrame(articles_data5)

# %%
df5
# Out:
#                                                  Title      Time Published  \
# 0    Best Apple Vision Pro Uses And Concepts: From ... 2024-02-05 10:26:53
# 1    Warren Buffett's Berkshire Hathaway Is Closing... 2024-02-05 10:06:00
# 2    Investor Optimism Improves Following Tech Earn... 2024-02-05 08:19:11
# 3    Apple Hailed As 'Table-Pounder' Tech Stock To ... 2024-02-05 07:20:44
# 4    Vision Pro's Future Version May Replace The iP... 2024-02-05 02:10:53
# ..                                                 ...                 ...
# 675  Market Making All The Right Moves; 4 Stocks In... 2024-01-12 22:14:00
# 676  Garmin Targeting Niche Markets In Smartwatches... 2024-01-12 21:46:00
# 677  2 Berkshire Hathaway Stocks to Buy Hand Over F... 2024-01-12 21:30:00
# 678  Dow Jones Falls; Big Banks Struggle After Earn... 2024-01-12 21:14:00
# 679  Why Microsoft's stock is a better investment t... 2024-01-12 18:30:00
#
#                                                Summary  \
# ...

# %%
url = 'https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=AAPL&apikey={key}&time_from=20230605T0000&time_to=20240112T1829&limit=1000'
r = requests.get(url)
data6 = r.json()

articles_data6 = []
for article in data6['feed']:
    article_info = {
        'Title': article['title'],
        'Time Published': pd.to_datetime(article['time_published'], format='%Y%m%dT%H%M%S'),
        'Summary': article['summary'],
        'Source': article['source'],
        'Topic': ', '.join(topic['topic'] for topic in article['topics']),
        'Sentiment Score': article['overall_sentiment_score'],
        'Sentiment Label': article['overall_sentiment_label'],
    }
    articles_data6.append(article_info)

df6 = pd.DataFrame(articles_data6)

# %%
df6
# Out:
#                                                  Title      Time Published  \
# 0    High import tariffs of mobile device parts off... 2024-01-12 17:57:07
# 1    Apple, American Express Led The Way For Buffet... 2024-01-12 15:42:16
# 2    Market Clubhouse Morning Memo - January 12th, ... 2024-01-12 15:22:33
# 3    5 Technology ETFs to Buy on a Rebound in PC Sales 2024-01-12 15:05:00
# 4    EU Cracks Down on Tech Giants: Apple, Alphabet... 2024-01-12 12:59:56
# ..                                                 ...                 ...
# 681  What's Going On With Intel Stock Thursday? - I... 2023-12-14 15:58:07
# 682  Market Clubhouse Morning Memo - December 14th,... 2023-12-14 15:30:28
# 683  Arm Gives Chipmakers A Leg Up In Semiconductor... 2023-12-14 15:28:00
# 684  The Rise of American Tech Power: Apple's Marke... 2023-12-14 15:26:11
# 685  Powell's Flip Risk Stock Market Animal Spirits... 2023-12-14 15:20:11
#
#                                                Summary  \
# ...

# %%
url = 'https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=AAPL&apikey={key}&time_from=20230605T0000&time_to=20231214T1419&limit=1000'
r = requests.get(url)
data7 = r.json()

articles_data7 = []
for article in data7['feed']:
    article_info = {
        'Title': article['title'],
        'Time Published': pd.to_datetime(article['time_published'], format='%Y%m%dT%H%M%S'),
        'Summary': article['summary'],
        'Source': article['source'],
        'Topic': ', '.join(topic['topic'] for topic in article['topics']),
        'Sentiment Score': article['overall_sentiment_score'],
        'Sentiment Label': article['overall_sentiment_label'],
    }
    articles_data7.append(article_info)

df7 = pd.DataFrame(articles_data7)

# %%
df7
# Out:
#                                                  Title      Time Published  \
# 0    5 Winning Stocks of 2023 as Dow Jones Hits New... 2023-12-14 14:09:00
# 1     Zacks Investment Ideas feature highlights: Apple 2023-12-14 14:01:00
# 2    Futures Rise Ahead Of Jobless Claims, Retail S... 2023-12-14 13:14:00
# 3    Tech Meets Tune: Universal Music's Lucian Grai... 2023-12-14 12:44:04
# 4    Want To Repair Your iPhone Or MacBook At Home?... 2023-12-14 12:27:10
# ..                                                 ...                 ...
# 673  Got $1,000? 3 Warren Buffett Stocks to Buy Han... 2023-11-15 11:45:00
# 674  Hedge-fund manager who called last year's tech... 2023-11-15 11:43:00
# 675  Should You Invest in the Technology Select Sec... 2023-11-15 11:20:06
# 676  iPhone 14 Users Get An Extra Year Of Free Emer... 2023-11-15 10:48:04
# 677  9 In 10 Teens Own And Will Buy An iPhone Next,... 2023-11-15 10:33:21
#
#                                                Summary  \
# ...

# %%
# joiing all of the dataframes together into one big dataframe
df_list = [df1, df2, df3, df4, df5, df6, df7]
apple_df = pd.concat(df_list, ignore_index=True)

# %%
# sorting the enteries by the date they were published
apple_df= apple_df.sort_values(by='Time Published')

# %%
# filtering the headlines by keywords relating to apple
keywords = ["AAPL", "Apple's", 'iPhone', 'MacBook', 'Siri', "Siri's"]
apple_df = apple_df[apple_df['Title'].str.contains('|'.join(keywords))]

# %%
apple_df
# Out:
#                                                   Title      Time Published  \
# 4782  9 In 10 Teens Own And Will Buy An iPhone Next,... 2023-11-15 10:33:21
# 4781  iPhone 14 Users Get An Extra Year Of Free Emer... 2023-11-15 10:48:04
# 4770  Apple, PepsiCo And 2 Other Stocks Insiders Are... 2023-11-15 13:02:50
# 4767  Apple And Google Could Face Consumption Tax Li... 2023-11-15 13:51:14
# 4761  Market Clubhouse Morning Memo - November 15th,... 2023-11-15 15:53:37
# ...                                                 ...                 ...
# 21    Apple's Upcoming Back To School Promotion Repo... 2024-06-05 05:12:38
# 19    Siri's AI Awakening? iOS 18 Promises iPhone Up... 2024-06-05 09:34:08
# 10    Market Clubhouse Morning Memo - June 5th, 2024... 2024-06-05 14:23:29
# 5     Does Apple's  ( AAPL )  AI Focus Make it a Buy... 2024-06-05 19:00:00
# 3     S&P 500, Nasdaq 100 Jointly Hit All-Time Highs... 2024-06-05 20:18:04
#
# ...

# %%
# saving the dataframe
apple_df.to_csv('/content/drive/My Drive/Research Project/apple_articles.csv', index=False)

# %% [markdown]
# Decided to collect more headlines for Apple over a linger time period

# %%
# reloading the dataframe
apple = pd.read_csv('/content/drive/My Drive/Research Project/apple_articles.csv')

# %%
apple
# Out:
#                                                   Title       Time Published  \
# 0     9 In 10 Teens Own And Will Buy An iPhone Next,...  2023-11-15 10:33:21
# 1     iPhone 14 Users Get An Extra Year Of Free Emer...  2023-11-15 10:48:04
# 2     Apple, PepsiCo And 2 Other Stocks Insiders Are...  2023-11-15 13:02:50
# 3     Apple And Google Could Face Consumption Tax Li...  2023-11-15 13:51:14
# 4     Market Clubhouse Morning Memo - November 15th,...  2023-11-15 15:53:37
# ...                                                 ...                  ...
# 1408  Apple's Upcoming Back To School Promotion Repo...  2024-06-05 05:12:38
# 1409  Siri's AI Awakening? iOS 18 Promises iPhone Up...  2024-06-05 09:34:08
# 1410  Market Clubhouse Morning Memo - June 5th, 2024...  2024-06-05 14:23:29
# 1411  Does Apple's  ( AAPL )  AI Focus Make it a Buy...  2024-06-05 19:00:00
# 1412  S&P 500, Nasdaq 100 Jointly Hit All-Time Highs...  2024-06-05 20:18:04
#
# ...

# %%
# start to collect more data
url = 'https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=AAPL&apikey={key}&time_from=20200605T0000&time_to=20231115T1032&limit=1000'
r = requests.get(url)
data8 = r.json()

articles_data8 = []
for article in data8['feed']:
    article_info = {
        'Title': article['title'],
        'Time Published': pd.to_datetime(article['time_published'], format='%Y%m%dT%H%M%S'),
        'Summary': article['summary'],
        'Source': article['source'],
        'Topic': ', '.join(topic['topic'] for topic in article['topics']),
        'Sentiment Score': article['overall_sentiment_score'],
        'Sentiment Label': article['overall_sentiment_label'],
    }
    articles_data8.append(article_info)

df8 = pd.DataFrame(articles_data8)

# %%
df8
# Out:
#                                                  Title      Time Published  \
# 0    The Embarrassingly Easy Way Warren Buffett Is ... 2023-11-15 10:06:00
# 1    Forget Apple: These 2 Stocks Are Better Buys f... 2023-11-15 10:00:00
# 2    Elon Musk, Satya Nadella Among Tech Leaders To... 2023-11-15 09:05:39
# 3    Apple's VisionOS Beta 6 Release Unveils Onboar... 2023-11-15 08:36:26
# 4    Buffett's Berkshire Trimmed Chevron Stake Whil... 2023-11-15 07:47:53
# ..                                                 ...                 ...
# 660  Guide to the Magnificent Seven Stocks & ETFs I... 2023-10-23 17:00:00
# 661  S&P 500 Breaches 200-Day Average As Treasury Y... 2023-10-23 15:34:46
# 662  Gold Bulls Excited, 10-Year Yield And Earnings... 2023-10-23 15:19:41
# 663  Market Clubhouse Morning Memo - October 23rd, ... 2023-10-23 14:49:59
# 664  Concerned that your Apple HomePod devices migh... 2023-10-23 13:56:55
#
# ...

# %%
url = 'https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=AAPL&apikey={key}&time_from=20200605T0000&time_to=20231023T1357&limit=1000'
r = requests.get(url)
data8 = r.json()

articles_data8 = []
for article in data8['feed']:
    article_info = {
        'Title': article['title'],
        'Time Published': pd.to_datetime(article['time_published'], format='%Y%m%dT%H%M%S'),
        'Summary': article['summary'],
        'Source': article['source'],
        'Topic': ', '.join(topic['topic'] for topic in article['topics']),
        'Sentiment Score': article['overall_sentiment_score'],
        'Sentiment Label': article['overall_sentiment_label'],
    }
    articles_data8.append(article_info)

df9 = pd.DataFrame(articles_data8)

# %%
df9
# Out:
#                                                  Title      Time Published  \
# 0    Concerned that your Apple HomePod devices migh... 2023-10-23 13:56:55
# 1    Apple's $1B Annual Investment Indicates Heavy ... 2023-10-23 13:31:33
# 2    1 Extraordinary ETF Every Growth Investor Shou... 2023-10-23 13:30:00
# 3    Garmin  ( GRMN )  Bolsters Smartwatch Offering... 2023-10-23 13:30:00
# 4                        Company News for Oct 23, 2023 2023-10-23 13:28:00
# ..                                                 ...                 ...
# 672  Investors Heavily Search Apple Inc.  ( AAPL ) ... 2023-09-25 13:00:12
# 673                 India ETFs Surge in Q3: Here's Why 2023-09-25 12:40:00
# 674  Apple's iOS 17 Update Challenges Google's Sear... 2023-09-25 11:52:57
# 675  'I Can't Stand How Wild This Is': Former Windo... 2023-09-25 11:46:11
# 676  An Oversold Market Faces Obstacles in the Week... 2023-09-25 11:32:00
#
# ...

# %%
url = 'https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=AAPL&apikey={key}&time_from=20200605T0000&time_to=20230925T1131&limit=1000'
r = requests.get(url)
data8 = r.json()

articles_data8 = []
for article in data8['feed']:
    article_info = {
        'Title': article['title'],
        'Time Published': pd.to_datetime(article['time_published'], format='%Y%m%dT%H%M%S'),
        'Summary': article['summary'],
        'Source': article['source'],
        'Topic': ', '.join(topic['topic'] for topic in article['topics']),
        'Sentiment Score': article['overall_sentiment_score'],
        'Sentiment Label': article['overall_sentiment_label'],
    }
    articles_data8.append(article_info)

df10 = pd.DataFrame(articles_data8)

# %%
df10
# Out:
#                                                  Title      Time Published  \
# 0    Semiconductor companies are in denial about th... 2023-09-25 11:18:00
# 1    Google Pixel 8 May Outshine Apple's iPhone Wit... 2023-09-25 11:06:38
# 2    Tim Cook And Teresa Perales Bond Over How The ... 2023-09-25 10:33:03
# 3    Should WisdomTree U.S. LargeCap Dividend ETF  ... 2023-09-25 10:20:07
# 4    Jamie Raskin's Warning On Government Shutdown,... 2023-09-25 10:08:52
# ..                                                 ...                 ...
# 683        3 Top E-Commerce Stocks to Buy in September 2023-09-05 15:00:00
# 684  ESPN's 'melting iceberg' is yet another challe... 2023-09-05 14:03:00
# 685  Dell Becomes One Of The Early Generative AI Wi... 2023-09-05 13:59:34
# 686  Arm's IPO could value the chip company at $52 ... 2023-09-05 13:48:00
# 687  Arm's IPO could value the chip company at $52 ... 2023-09-05 13:48:00
#
# ...

# %%
url = 'https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=AAPL&apikey={key}&time_from=20200605T0000&time_to=20230905T1347&limit=1000'
r = requests.get(url)
data8 = r.json()

articles_data8 = []
for article in data8['feed']:
    article_info = {
        'Title': article['title'],
        'Time Published': pd.to_datetime(article['time_published'], format='%Y%m%dT%H%M%S'),
        'Summary': article['summary'],
        'Source': article['source'],
        'Topic': ', '.join(topic['topic'] for topic in article['topics']),
        'Sentiment Score': article['overall_sentiment_score'],
        'Sentiment Label': article['overall_sentiment_label'],
    }
    articles_data8.append(article_info)

df11 = pd.DataFrame(articles_data8)

# %%
df11
# Out:
#                                                  Title      Time Published  \
# 0    New iPhone 15 Pro Case Leak Reveals The Rumore... 2023-09-05 13:42:00
# 1    Market Clubhouse Morning Memo - September 5th,... 2023-09-05 13:40:24
# 2    What's Going On With Nvidia Stock Tuesday? - N... 2023-09-05 13:36:06
# 3    Apple Folded, But Why On Earth Is Tom Cruise's... 2023-09-05 12:34:52
# 4    A Bull Market Could Be Here: 2 Reasons to Buy ... 2023-09-05 12:30:00
# ..                                                 ...                 ...
# 674                       Better Buy: Apple vs. Amazon 2023-08-07 12:39:12
# 675  What's Going On With Apple Stock Monday? - App... 2023-08-07 12:26:32
# 676         5 Best Inverse/Leveraged ETFs of Last Week 2023-08-07 12:18:00
# 677  Futures Hover As Wall Street Braces For Inflat... 2023-08-07 12:13:00
# 678  One 'Magnificent 7' Stock Is Still Undervalued... 2023-08-07 12:00:00
#
#                                                Summary  \
# ...

# %%
url = 'https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=AAPL&apikey={key}&time_from=20200605T0000&time_to=20230807T1159&limit=1000'
r = requests.get(url)
data8 = r.json()

articles_data8 = []
for article in data8['feed']:
    article_info = {
        'Title': article['title'],
        'Time Published': pd.to_datetime(article['time_published'], format='%Y%m%dT%H%M%S'),
        'Summary': article['summary'],
        'Source': article['source'],
        'Topic': ', '.join(topic['topic'] for topic in article['topics']),
        'Sentiment Score': article['overall_sentiment_score'],
        'Sentiment Label': article['overall_sentiment_label'],
    }
    articles_data8.append(article_info)

df12 = pd.DataFrame(articles_data8)

# %%
df12
# Out:
#                                                  Title      Time Published  \
# 0    S&P 500 in danger of breaching support as tech... 2023-08-07 11:53:00
# 1    National Debt, Real Jobs, US Dollar Index, Cha... 2023-08-07 11:40:43
# 2             Conditions Are Aligned for More Downside 2023-08-07 11:15:19
# 3    Deal Alert: Save $700 On Apple's 14-Inch MacBo... 2023-08-07 11:02:52
# 4    US Stocks: Analyst Says 3 Factors Can Take S&P... 2023-08-07 10:54:35
# ..                                                 ...                 ...
# 649  Double Strike In Hollywood: Actors And Writers... 2023-07-13 20:41:41
# 650  Stocks Run With Big Earnings, Nasdaq Rebalance... 2023-07-13 20:40:00
# 651                                 What Is Cash Flow? 2023-07-13 20:37:34
# 652           What Are Retained Earnings in Investing? 2023-07-13 20:27:10
# 653  Stock Market Today: Stocks Extend Win Streak A... 2023-07-13 20:14:44
#
#                                                Summary  \
# ...

# %%
url = 'https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=AAPL&apikey={key}&time_from=20200605T0000&time_to=20230713T1913&limit=1000'
r = requests.get(url)
data8 = r.json()

articles_data8 = []
for article in data8['feed']:
    article_info = {
        'Title': article['title'],
        'Time Published': pd.to_datetime(article['time_published'], format='%Y%m%dT%H%M%S'),
        'Summary': article['summary'],
        'Source': article['source'],
        'Topic': ', '.join(topic['topic'] for topic in article['topics']),
        'Sentiment Score': article['overall_sentiment_score'],
        'Sentiment Label': article['overall_sentiment_label'],
    }
    articles_data8.append(article_info)

df13 = pd.DataFrame(articles_data8)

# %%
df13
# Out:
#                                                  Title      Time Published  \
# 0    Cat treats and Liquid I.V. What do Amazon Prim... 2023-07-13 18:20:00
# 1          Tune Into the Launch of the First Music ETF 2023-07-13 15:15:00
# 2    Apple's  ( AAPL )  Streaming Service Receives ... 2023-07-13 15:08:00
# 3    Dow Buoyant As Cooling Inflation Raises Hopes ... 2023-07-13 15:05:00
# 4    Market Clubhouse Morning Memo - July 13th, 202... 2023-07-13 14:29:45
# ..                                                 ...                 ...
# 665  Clumsy Hands? New Apple Patent Shows Future iP... 2023-06-16 12:47:21
# 666        Tech Futures Rise Ahead Of Inflation Survey 2023-06-16 12:17:00
# 667  10 Stocks Soar To Highs Investors Have Never S... 2023-06-16 12:00:00
# 668  Is SPDR MSCI USA StrategicFactors ETF  ( QUS )... 2023-06-16 10:20:06
# 669  The Words Apple Never Utters During An Event: ... 2023-06-16 10:10:25
#
#                                                Summary  \
# ...

# %%
url = 'https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=AAPL&apikey={key}&time_from=20200605T0000&time_to=20230616T1009&limit=1000'
r = requests.get(url)
data8 = r.json()

articles_data8 = []
for article in data8['feed']:
    article_info = {
        'Title': article['title'],
        'Time Published': pd.to_datetime(article['time_published'], format='%Y%m%dT%H%M%S'),
        'Summary': article['summary'],
        'Source': article['source'],
        'Topic': ', '.join(topic['topic'] for topic in article['topics']),
        'Sentiment Score': article['overall_sentiment_score'],
        'Sentiment Label': article['overall_sentiment_label'],
    }
    articles_data8.append(article_info)

df14 = pd.DataFrame(articles_data8)

# %%
df14
# Out:
#                                                  Title      Time Published  \
# 0    Market Volatility Increases; S&P 500 Settles H... 2023-06-16 10:08:38
# 1    3 Growth Stocks That Could Be Huge Winners in ... 2023-06-16 09:35:00
# 2    Warren Buffett Is Raking in $5.17 Billion in A... 2023-06-16 09:06:00
# 3    China's Xi greets 'old friend' Bill Gates in f... 2023-06-16 08:08:00
# 4    China's Xi greets 'old friend' Bill Gates in f... 2023-06-16 08:08:00
# ..                                                 ...                 ...
# 678  Meta fined record $1.3 billion by EU regulator... 2023-05-22 09:28:10
# 679  Warren Buffett's Portfolio Is More Concentrate... 2023-05-22 09:06:00
# 680  Apple Stake Boosted By Power Corp Of Canada Wh... 2023-05-22 07:31:56
# 681  Apple's Next Big Surprise? 'xrProOS' Trademark... 2023-05-22 06:46:40
# 682                       Better Buy: Apple vs. Nvidia 2023-05-21 16:15:00
#
# ...

# %%
url = 'https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=AAPL&apikey={key}&time_from=20200605T0000&time_to=20230521T1614&limit=1000'
r = requests.get(url)
data8 = r.json()

articles_data8 = []
for article in data8['feed']:
    article_info = {
        'Title': article['title'],
        'Time Published': pd.to_datetime(article['time_published'], format='%Y%m%dT%H%M%S'),
        'Summary': article['summary'],
        'Source': article['source'],
        'Topic': ', '.join(topic['topic'] for topic in article['topics']),
        'Sentiment Score': article['overall_sentiment_score'],
        'Sentiment Label': article['overall_sentiment_label'],
    }
    articles_data8.append(article_info)

df15 = pd.DataFrame(articles_data8)

# %%
df15
# Out:
#                                                  Title      Time Published  \
# 0    Megacap tech stocks out of control? Big Tech s... 2023-05-21 16:01:00
# 1    Investor Behind Top Global ETF Sees Bearish Tr... 2023-05-21 13:57:34
# 2    Investor Behind Top Global ETF Sees Bearish Tr... 2023-05-21 13:57:33
# 3    Why Apple, Comcast, and Warner Bros. Discovery... 2023-05-21 12:30:00
# 4    Got $1,000? 5 Buffett Stocks to Buy and Hold F... 2023-05-21 10:04:00
# ..                                                 ...                 ...
# 660  Soldering in Electronics Assembly Market Worth... 2023-04-25 14:56:46
# 661   Why Apple's Expansion Into India Is a Great Move 2023-04-25 14:19:11
# 662  Sleep Easy With These 2 Rock-Solid Dividend St... 2023-04-25 13:53:00
# 663                      Company News for Apr 25, 2023 2023-04-25 13:03:00
# 664  Masimo and Black Knight have been highlighted ... 2023-04-25 12:43:00
#
# ...

# %%
url = 'https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=AAPL&apikey={key}&time_from=20200605T0000&time_to=20230425T1243&limit=1000'
r = requests.get(url)
data8 = r.json()

articles_data8 = []
for article in data8['feed']:
    article_info = {
        'Title': article['title'],
        'Time Published': pd.to_datetime(article['time_published'], format='%Y%m%dT%H%M%S'),
        'Summary': article['summary'],
        'Source': article['source'],
        'Topic': ', '.join(topic['topic'] for topic in article['topics']),
        'Sentiment Score': article['overall_sentiment_score'],
        'Sentiment Label': article['overall_sentiment_label'],
    }
    articles_data8.append(article_info)

df16 = pd.DataFrame(articles_data8)

# %%
df16
# Out:
#                                                  Title      Time Published  \
# 0    Masimo and Black Knight have been highlighted ... 2023-04-25 12:43:00
# 1    Apple supplier Corning rides on price hikes to... 2023-04-25 12:22:57
# 2           Futures Fall Amid Wave Of Earnings Reports 2023-04-25 12:18:00
# 3    Warren Buffett's Berkshire Could Join Apple, M... 2023-04-25 12:00:00
# 4             Where to Invest $10,000 in a Bear Market 2023-04-25 11:37:00
# ..                                                 ...                 ...
# 687  S&P 500 Edges Higher, Market Volatility Decrea... 2023-03-28 10:05:51
# 688  Futures muted as yields rise amid easing bank ... 2023-03-28 09:52:00
# 689  TikTok Ban Nearly Certain, Says Analyst - But ... 2023-03-28 09:40:39
# 690  If You Invested $25,000 in Warren Buffett's 5 ... 2023-03-28 09:30:00
# 691  Smart, sleek and streamlined: Here's how the l... 2023-03-28 09:01:00
#
#                                                Summary  \
# ...

# %%
url = 'https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=AAPL&apikey={key}&time_from=20200605T0000&time_to=20230328T0900&limit=1000'
r = requests.get(url)
data8 = r.json()

articles_data8 = []
for article in data8['feed']:
    article_info = {
        'Title': article['title'],
        'Time Published': pd.to_datetime(article['time_published'], format='%Y%m%dT%H%M%S'),
        'Summary': article['summary'],
        'Source': article['source'],
        'Topic': ', '.join(topic['topic'] for topic in article['topics']),
        'Sentiment Score': article['overall_sentiment_score'],
        'Sentiment Label': article['overall_sentiment_label'],
    }
    articles_data8.append(article_info)

df17 = pd.DataFrame(articles_data8)

# %%
df17
# Out:
#                                                  Title      Time Published  \
# 0    U.S. stock futures stable while tech companies... 2023-03-28 08:55:00
# 1    Nasdaq 100: Is a new bull market in place? | T... 2023-03-28 06:39:32
# 2    Apple Music Classical Now Available For Downlo... 2023-03-28 06:31:04
# 3    Why Warren Buffett Will Never Buy Tesla Stock:... 2023-03-28 05:35:20
# 4    Apple iOS 16.4: What You Need To Know Before U... 2023-03-28 04:08:52
# ..                                                 ...                 ...
# 681  Taiwan Semiconductor Manufacturing Eyes Second... 2023-02-24 09:41:35
# 682  WhatsApp To Bring iMessage-like Feature To And... 2023-02-24 09:25:16
# 683  PineBridge looks past Adani saga to load up on... 2023-02-24 02:06:25
# 684  Smart machines market size is set to grow at a... 2023-02-24 02:00:00
# 685  Tesla, Amazon, Alphabet, Nvidia, Intel: Trendi... 2023-02-24 01:12:22
#
# ...

# %%
url = 'https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=AAPL&apikey={key}&time_from=20200605T0000&time_to=20230224T0111&limit=1000'
r = requests.get(url)
data8 = r.json()

articles_data8 = []
for article in data8['feed']:
    article_info = {
        'Title': article['title'],
        'Time Published': pd.to_datetime(article['time_published'], format='%Y%m%dT%H%M%S'),
        'Summary': article['summary'],
        'Source': article['source'],
        'Topic': ', '.join(topic['topic'] for topic in article['topics']),
        'Sentiment Score': article['overall_sentiment_score'],
        'Sentiment Label': article['overall_sentiment_label'],
    }
    articles_data8.append(article_info)

df18 = pd.DataFrame(articles_data8)

# %%
df18
# Out:
#                                                  Title      Time Published  \
# 0    Berkshire Earnings: Should Investors Buy Warre... 2023-02-23 22:08:00
# 1          ETF Strategies to Protect Against Inflation 2023-02-23 21:48:00
# 2    Unity Software stock slides nearly 20% as mobi... 2023-02-23 19:39:00
# 3    Stock Futures and Yields Skip Ahead as Market ... 2023-02-23 19:31:56
# 4    Netflix drops prices in over 30 countries amid... 2023-02-23 17:47:00
# ..                                                 ...                 ...
# 663  Amazon, Apple, Alphabet Headline Another Busy ... 2023-01-28 13:26:00
# 664   Big Banks Try to Take On Apple Wallet and PayPal 2023-01-28 12:00:00
# 665  Investing Action Plan - January Wrap: Apple, O... 2023-01-27 23:20:00
# 666  Tech stocks are having their best January in d... 2023-01-27 22:31:00
# 667  Why This May Be A Life-Changing Rally; Apple, ... 2023-01-27 22:21:00
#
#                                                Summary  \
# ...

# %%
url = 'https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=AAPL&apikey={key}&time_from=20200605T0000&time_to=20230127T2220&limit=1000'
r = requests.get(url)
data8 = r.json()

articles_data8 = []
for article in data8['feed']:
    article_info = {
        'Title': article['title'],
        'Time Published': pd.to_datetime(article['time_published'], format='%Y%m%dT%H%M%S'),
        'Summary': article['summary'],
        'Source': article['source'],
        'Topic': ', '.join(topic['topic'] for topic in article['topics']),
        'Sentiment Score': article['overall_sentiment_score'],
        'Sentiment Label': article['overall_sentiment_label'],
    }
    articles_data8.append(article_info)

df19 = pd.DataFrame(articles_data8)

# %%
df19
# Out:
#                                                  Title      Time Published  \
# 0    Apple Takes The Cake Again In China As Top Sma... 2023-01-27 21:48:51
# 1    Stock Market Today: Stocks End the Week on a H... 2023-01-27 21:14:34
# 2    Will This Week's Big Tech Earnings Be a Train ... 2023-01-27 19:39:00
# 3    Apple Stock Climbs Wall Of Worry Ahead Of Earn... 2023-01-27 18:13:00
# 4    Meta's 'darkest days' are ahead, but some anal... 2023-01-27 17:31:00
# ..                                                 ...                 ...
# 683  U.S. stock futures rise as traders eye looming... 2023-01-04 10:01:00
# 684  Investor Fear Increases Slightly As US Stocks ... 2023-01-04 08:04:48
# 685  Investor Fear Increases Slightly As US Stocks ... 2023-01-04 08:04:02
# 686  CES 2023: A new 'metaverse' headset gets early... 2023-01-04 02:56:00
# 687  Apple Crossed The Whopping $3 Trillion Mark Ex... 2023-01-04 02:14:50
#
#                                                Summary  \
# ...

# %%
url = 'https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=AAPL&apikey={key}&time_from=20200605T0000&time_to=20230104T0213&limit=1000'
r = requests.get(url)
data8 = r.json()

articles_data8 = []
for article in data8['feed']:
    article_info = {
        'Title': article['title'],
        'Time Published': pd.to_datetime(article['time_published'], format='%Y%m%dT%H%M%S'),
        'Summary': article['summary'],
        'Source': article['source'],
        'Topic': ', '.join(topic['topic'] for topic in article['topics']),
        'Sentiment Score': article['overall_sentiment_score'],
        'Sentiment Label': article['overall_sentiment_label'],
    }
    articles_data8.append(article_info)

df20 = pd.DataFrame(articles_data8)

# %%
df20
# Out:
#                                                  Title      Time Published  \
# 0    New Year, Old Woes For Stocks; Apple, Tesla Tu... 2023-01-04 01:38:00
# 1    Tesla, Amazon, Apple, Aurinia Pharma, Vera The... 2023-01-04 01:09:13
# 2    Wall Street starts the year with a dip; Apple,... 2023-01-04 00:33:47
# 3    EXCLUSIVE: Top 10 Searched Tickers On Pro In D... 2023-01-03 23:54:34
# 4                Valuation Squeezes Continue into 2023 2023-01-03 22:38:00
# ..                                                 ...                 ...
# 682  Billionaire Mark Cuban Becomes Elon Musk's Mos... 2022-12-06 14:24:00
# 683  Here is What to Know Beyond Why Apple Inc.  ( ... 2022-12-06 14:00:13
# 684  Goldman Sachs Plans Investing In FTX Hit Firms... 2022-12-06 13:25:16
# 685  Apple's 'Always-On' Feature Draining Your iPho... 2022-12-06 13:17:03
# 686      Futures Look To Rebound After Market Sell-Off 2022-12-06 13:12:00
#
#                                                Summary  \
# ...

# %%
url = 'https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=AAPL&apikey={key}&time_from=20200605T0000&time_to=20221206T1311&limit=1000'
r = requests.get(url)
data8 = r.json()

articles_data8 = []
for article in data8['feed']:
    article_info = {
        'Title': article['title'],
        'Time Published': pd.to_datetime(article['time_published'], format='%Y%m%dT%H%M%S'),
        'Summary': article['summary'],
        'Source': article['source'],
        'Topic': ', '.join(topic['topic'] for topic in article['topics']),
        'Sentiment Score': article['overall_sentiment_score'],
        'Sentiment Label': article['overall_sentiment_label'],
    }
    articles_data8.append(article_info)

df21 = pd.DataFrame(articles_data8)

# %%
df21
# Out:
#                                                  Title      Time Published  \
# 0    This Apple Option Saw Massive Surge In Volumes... 2022-12-06 11:55:41
# 1    Should Engine No. 1 Transform 500 ETF  ( VOTE ... 2022-12-06 11:20:10
# 2    Should Vanguard LargeCap ETF  ( VV )  Be on Yo... 2022-12-06 11:20:06
# 3    TSMC Plans $40 Billion U.S. Investment As Pres... 2022-12-06 10:48:00
# 4    Air Products Stock Could Be a Hidden Gem Among... 2022-12-06 10:40:00
# ..                                                 ...                 ...
# 688  China eases some quarantine for travelers even... 2022-11-11 03:49:19
# 689  Nasdaq 100 adds $700 billion in value as US in... 2022-11-11 01:49:35
# 690  Breaking Down Target  ( TGT )  Stock Before Q3... 2022-11-11 01:45:00
# 691                    Stock Buybacks Are Here to Stay 2022-11-11 01:11:11
# 692  Buffett's Berkshire sheds large portion of US ... 2022-11-11 01:06:00
#
# ...

# %%
url = 'https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=AAPL&apikey={key}&time_from=20200605T0000&time_to=20221111T0105&limit=1000'
r = requests.get(url)
data8 = r.json()

articles_data8 = []
for article in data8['feed']:
    article_info = {
        'Title': article['title'],
        'Time Published': pd.to_datetime(article['time_published'], format='%Y%m%dT%H%M%S'),
        'Summary': article['summary'],
        'Source': article['source'],
        'Topic': ', '.join(topic['topic'] for topic in article['topics']),
        'Sentiment Score': article['overall_sentiment_score'],
        'Sentiment Label': article['overall_sentiment_label'],
    }
    articles_data8.append(article_info)

df22 = pd.DataFrame(articles_data8)

# %%
df22
# Out:
#                                                  Title      Time Published  \
# 0    Amazon, Apple, Tesla, Root, Toast: Expense Rev... 2022-11-11 01:01:29
# 1    Your iPhone Is Susceptible To Malware Attack E... 2022-11-10 22:13:09
# 2    'Real big sigh of relief': Stock, bond ETFs ju... 2022-11-10 22:01:00
# 3    Stocks Soar On Inflation Data: Why The Rally H... 2022-11-10 21:54:00
# 4    Stock Market Today: Stocks Lift Off After Enco... 2022-11-10 21:20:04
# ..                                                 ...                 ...
# 669   Verisk Analytics Is No. 3 On IBD's 2022 ESG List 2022-10-24 11:00:00
# 670  First Solar: Mindful Manufacturer And Solar Pa... 2022-10-24 11:00:00
# 671   The Three Best ESG Companies In Eight Industries 2022-10-24 11:00:00
# 672  Xi Jinping Cements Dominance With Historic 3rd... 2022-10-24 10:54:22
# 673  This hedge fund manager who made winning bets ... 2022-10-24 10:32:00
#
#                                                Summary  \
# ...

# %%
url = 'https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=AAPL&apikey={key}&time_from=20200605T0000&time_to=20221024T1031&limit=1000'
r = requests.get(url)
data8 = r.json()

articles_data8 = []
for article in data8['feed']:
    article_info = {
        'Title': article['title'],
        'Time Published': pd.to_datetime(article['time_published'], format='%Y%m%dT%H%M%S'),
        'Summary': article['summary'],
        'Source': article['source'],
        'Topic': ', '.join(topic['topic'] for topic in article['topics']),
        'Sentiment Score': article['overall_sentiment_score'],
        'Sentiment Label': article['overall_sentiment_label'],
    }
    articles_data8.append(article_info)

df23 = pd.DataFrame(articles_data8)

# %%
df23
# Out:
#                                                  Title      Time Published  \
# 0    Investor Sentiment Improves Ahead Of Earnings ... 2022-10-24 10:27:40
# 1    China Tech Stocks Crushed As Xi Secures 3rd Te... 2022-10-24 10:21:00
# 2    Is iShares MSCI ACWI Low Carbon Target ETF  ( ... 2022-10-24 10:20:08
# 3    Apple Has Missed A Beat With 2022 iPad Line, E... 2022-10-24 10:14:30
# 4    Ramsey Solutions Launches Gazelle, A Debit Car... 2022-10-24 10:00:00
# ..                                                 ...                 ...
# 654  The No. 1 Quality That Top Stocks Share  ( and... 2022-10-02 16:57:00
# 655  Third Leg Down For Bear? Tesla Deliveries Fall... 2022-10-02 16:19:00
# 656      Will Amazon Be Worth More Than Apple by 2025? 2022-10-02 13:45:00
# 657  Apple Shares Have More Downside Ahead - Apple ... 2022-10-02 12:39:26
# 658  Chinese stocks fell US$5 trillion due to zero-... 2022-10-02 07:15:11
#
#                                                Summary  \
# ...

# %%
url = 'https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=AAPL&apikey={key}&time_from=20200605T0000&time_to=20221002T0714&limit=1000'
r = requests.get(url)
data8 = r.json()

articles_data8 = []
for article in data8['feed']:
    article_info = {
        'Title': article['title'],
        'Time Published': pd.to_datetime(article['time_published'], format='%Y%m%dT%H%M%S'),
        'Summary': article['summary'],
        'Source': article['source'],
        'Topic': ', '.join(topic['topic'] for topic in article['topics']),
        'Sentiment Score': article['overall_sentiment_score'],
        'Sentiment Label': article['overall_sentiment_label'],
    }
    articles_data8.append(article_info)

df24 = pd.DataFrame(articles_data8)

# %%
df24
# Out:
#                                                  Title      Time Published  \
# 0    China's $5 trillion rout creates historic gap ... 2022-10-02 02:10:00
# 1    Facebook parent Meta is no longer one of 10 mo... 2022-10-01 22:22:00
# 2    Tesla, Apple, Meta And Why Michael Burry Says ... 2022-10-01 21:13:09
# 3    Everything Elon Musk Said At Tesla AI Day to S... 2022-10-01 20:42:00
# 4                          Costco Continues to Deliver 2022-10-01 18:54:00
# ..                                                 ...                 ...
# 672  ROKU Set to Launch The Rich Eisen Show on The ... 2022-09-09 17:57:00
# 673  Apple  ( AAPL )  Expands TV+ Content With Sele... 2022-09-09 17:17:00
# 674  Tata Group in talks with Wistron for manufactu... 2022-09-09 15:26:00
# 675  Top headlines: Indian forex reserves, Kharif r... 2022-09-09 14:58:00
# 676  3 Top Tech Stocks That Could Help Make You Ric... 2022-09-09 14:15:00
#
# ...

# %%
url = 'https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=AAPL&apikey={key}&time_from=20200605T0000&time_to=20220909T1414&limit=1000'
r = requests.get(url)
data8 = r.json()

articles_data8 = []
for article in data8['feed']:
    article_info = {
        'Title': article['title'],
        'Time Published': pd.to_datetime(article['time_published'], format='%Y%m%dT%H%M%S'),
        'Summary': article['summary'],
        'Source': article['source'],
        'Topic': ', '.join(topic['topic'] for topic in article['topics']),
        'Sentiment Score': article['overall_sentiment_score'],
        'Sentiment Label': article['overall_sentiment_label'],
    }
    articles_data8.append(article_info)

df25 = pd.DataFrame(articles_data8)

# %%
df25
# Out:
#                                                  Title      Time Published  \
# 0    Walt Disney  ( NYSE:DIS )  - Who Wins The Stre... 2022-09-09 13:41:29
# 1    Top Funds Bet Over $1 Billion On Five Stocks, ... 2022-09-09 12:45:00
# 2    Bitcoin  ( BTC/USD ) , Ethereum  ( ETH/USD )  ... 2022-09-09 12:43:49
# 3    NVIDIA  ( NASDAQ:NVDA ) , Apple  ( NASDAQ:AAPL... 2022-09-09 12:26:44
# 4    Alphabet  ( NASDAQ:GOOG ) , Alphabet  ( NASDAQ... 2022-09-09 12:21:47
# ..                                                 ...                 ...
# 667  The 2022 Mercedes-Benz GLA: This small, spunky... 2022-08-16 09:01:00
# 668  Dow Jumps Over 150 points But Market Volatilit... 2022-08-16 07:06:47
# 669  Apple gears up for return to normal with offic... 2022-08-16 06:03:15
# 670  Slowing economy reaches Apple as it lays off 1... 2022-08-16 05:53:00
# 671  Apple lays off recruiters in a push to rein in... 2022-08-16 04:40:00
#
#                                                Summary  \
# ...

# %%
url = 'https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=AAPL&apikey={key}&time_from=20200605T0000&time_to=20220816T0439&limit=1000'
r = requests.get(url)
data8 = r.json()

articles_data8 = []
for article in data8['feed']:
    article_info = {
        'Title': article['title'],
        'Time Published': pd.to_datetime(article['time_published'], format='%Y%m%dT%H%M%S'),
        'Summary': article['summary'],
        'Source': article['source'],
        'Topic': ', '.join(topic['topic'] for topic in article['topics']),
        'Sentiment Score': article['overall_sentiment_score'],
        'Sentiment Label': article['overall_sentiment_label'],
    }
    articles_data8.append(article_info)

df26 = pd.DataFrame(articles_data8)

# %%
df26
# Out:
#                                                  Title      Time Published  \
# 0    Wall Street climbs, adding to recent gains as ... 2022-08-16 00:44:42
# 1    Apple wants workers back in the office 3 days ... 2022-08-15 23:52:00
# 2    Buffett Remains Bullish On Oil, Adds to Chevro... 2022-08-15 23:46:00
# 3    Buffett Buys More Apple, Chevron, Occidental P... 2022-08-15 23:21:43
# 4    Apple sets Sept 5 deadline for employees to re... 2022-08-15 22:33:00
# ..                                                 ...                 ...
# 654  Wall Street Week Ahead: Strong dollar looms ov... 2022-07-24 11:46:20
# 655  3 Stocks the World's Greatest Investors Like t... 2022-07-24 11:03:00
# 656  Snap, Twitter Lead Social Media Stocks Lower F... 2022-07-23 21:11:38
# 657       Impatience Can Be Costly During Bear Markets 2022-07-23 13:30:00
# 658  Taiwan Semiconductor Is Saying Chip Demand Rem... 2022-07-23 13:26:00
#
# ...

# %%
url = 'https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=AAPL&apikey={key}&time_from=20200605T0000&time_to=20220723T1325&limit=1000'
r = requests.get(url)
data8 = r.json()

articles_data8 = []
for article in data8['feed']:
    article_info = {
        'Title': article['title'],
        'Time Published': pd.to_datetime(article['time_published'], format='%Y%m%dT%H%M%S'),
        'Summary': article['summary'],
        'Source': article['source'],
        'Topic': ', '.join(topic['topic'] for topic in article['topics']),
        'Sentiment Score': article['overall_sentiment_score'],
        'Sentiment Label': article['overall_sentiment_label'],
    }
    articles_data8.append(article_info)

df27 = pd.DataFrame(articles_data8)

# %%
df27
# Out:
#                                                  Title      Time Published  \
# 0    Does Nancy Pelosi Share Stock Tips With Her Hu... 2022-07-23 12:37:11
# 1    It's the end of 'fantasyland' for Big Tech and... 2022-07-23 12:10:00
# 2         Why One Size Doesn't Fit All Dividend Stocks 2022-07-23 12:00:00
# 3    Apple Outperforms Market, But Are Big Growth D... 2022-07-23 11:15:00
# 4     Time for Investors to Buy Big Tech Stocks Again? 2022-07-22 20:52:00
# ..                                                 ...                 ...
# 670  Stock Market Today: Dow Jones, S&P 500 Tick Lo... 2022-06-27 14:24:47
# 671  Meta Platforms  ( META )  Develops 3 New AI Mo... 2022-06-27 14:15:00
# 672  Apple Mixed Reality Headset Could Feature The ... 2022-06-27 13:56:25
# 673     Stocks Reverse Lower As Market Rally Continues 2022-06-27 13:55:00
# 674                 Stock Market News for Jun 27, 2022 2022-06-27 13:33:00
#
#                                                Summary  \
# ...

# %%
url = 'https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=AAPL&apikey={key}&time_from=20200605T0000&time_to=20220627T1332&limit=1000'
r = requests.get(url)
data8 = r.json()

articles_data8 = []
for article in data8['feed']:
    article_info = {
        'Title': article['title'],
        'Time Published': pd.to_datetime(article['time_published'], format='%Y%m%dT%H%M%S'),
        'Summary': article['summary'],
        'Source': article['source'],
        'Topic': ', '.join(topic['topic'] for topic in article['topics']),
        'Sentiment Score': article['overall_sentiment_score'],
        'Sentiment Label': article['overall_sentiment_label'],
    }
    articles_data8.append(article_info)

df28 = pd.DataFrame(articles_data8)

# %%
df28
# Out:
#                                                  Title      Time Published  \
# 0    This Advertising Company Has A Better 5-Year R... 2022-06-27 13:29:00
# 1      Will Nvidia Be a Trillion-Dollar Stock by 2025? 2022-06-27 12:48:00
# 2    2 Years Later, How This Discord Has Done Thing... 2022-06-27 12:42:51
# 3    Wall Street set to extend bounce as inflation ... 2022-06-27 11:34:40
# 4    Wall St set to extend bounce as inflation fear... 2022-06-27 11:19:00
# ..                                                 ...                 ...
# 672  3 Balanced Mutual Funds to Beat Volatile Marke... 2022-06-01 13:00:00
# 673  You Can Expect Google Pixel Watch's Battery To... 2022-06-01 11:40:19
# 674  Should SPDR S&P 500 ETF  ( SPY )  Be on Your I... 2022-06-01 10:20:09
# 675  Should Engine No. 1 Transform 500 ETF  ( VOTE ... 2022-06-01 10:20:08
# 676  Is SPDR MSCI USA StrategicFactors ETF  ( QUS )... 2022-06-01 10:20:06
#
# ...

# %%
# joining the dataframes together again
df_list = [df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20,df21,df22,df23,df24,df25,df26,df27,df28]
apple_df_2 = pd.concat(df_list, ignore_index=True)

# %%
apple_df_2.to_csv('/content/drive/My Drive/Research Project/apple_df_2.csv')

# %% [markdown]
# I collected even more headlines than this, however I cannot find the code but i did save the dataframe prior to it being lost.

# %%
# loading the 3rd data set with collected headlines
apple_df_3 = pd.read_csv('/content/drive/My Drive/Research Project/apple_df_3.csv')

# %%
apple_df_3
# Out:
#       Unnamed: 0                                              Title  \
# 0              0         Apple Hides Cool AR Feature In WWDC Invite
# 1              1  The superb, sharply-styled 2022 Kia K5 builds ...
# 2              2  $40 Leather Cover Helps You Find Your Lost App...
# 3              3  Which Companies Are Paying The Typical Worker ...
# 4              4  Dow Jones Dips As Apple Rallies; Tesla Stock S...
# ...          ...                                                ...
# 2771          97  Market Rallies, But Still Must Do This; 5 Stoc...
# 2772          98  Rich Russians turn to luxury jewellery, watche...
# 2773          99  Russia says its economy is taking 'serious blo...
# 2774         100  Apple halts product sales in Russia after Ukra...
# 2775         101  US stocks fall, oil tops $105 as Ukraine crisi...
#
#            Time Published                                            Summary  \
# ...

# %%
# joining the  2nd and 3rd dataframe together
df_list =[apple_df_2, apple_df_3]
apple_df = pd.concat(df_list, ignore_index=True)

# %%
# filter by keywords again
keywords = ["AAPL", "Apple's", 'iPhone', 'MacBook', 'Siri', "Siri's"]
apple_df = apple_df[apple_df['Title'].str.contains('|'.join(keywords))]

# %%
# convert time published into  datetime
apple_df['Time Published'] = pd.to_datetime(apple_df['Time Published'])

# Sortin dataframe by time published
apple_df = apple_df.sort_values(by='Time Published')

# %%
# load the original data frame (the one collected first before deciding to extended the time frame)
original_apple = pd.read_csv('/content/drive/My Drive/Research Project/apple_articles.csv')

# %%
original_apple
# Out:
#                                                   Title       Time Published  \
# 0     9 In 10 Teens Own And Will Buy An iPhone Next,...  2023-11-15 10:33:21
# 1     iPhone 14 Users Get An Extra Year Of Free Emer...  2023-11-15 10:48:04
# 2     Apple, PepsiCo And 2 Other Stocks Insiders Are...  2023-11-15 13:02:50
# 3     Apple And Google Could Face Consumption Tax Li...  2023-11-15 13:51:14
# 4     Market Clubhouse Morning Memo - November 15th,...  2023-11-15 15:53:37
# ...                                                 ...                  ...
# 1408  Apple's Upcoming Back To School Promotion Repo...  2024-06-05 05:12:38
# 1409  Siri's AI Awakening? iOS 18 Promises iPhone Up...  2024-06-05 09:34:08
# 1410  Market Clubhouse Morning Memo - June 5th, 2024...  2024-06-05 14:23:29
# 1411  Does Apple's  ( AAPL )  AI Focus Make it a Buy...  2024-06-05 19:00:00
# 1412  S&P 500, Nasdaq 100 Jointly Hit All-Time Highs...  2024-06-05 20:18:04
#
# ...

# %%
# join the two together
df = pd.concat([apple_df, original_apple])

# %%
apple_df = df

# %%
# save the final dataframe
apple_df.to_csv('/content/drive/My Drive/Research Project/apple_articles_2022_2024.csv')

# %% [markdown]
# # Collecting Apple Stock Data

# %%
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=AAPL&outputsize=full&apikey={key}&datatype=csv'

# %%
apple_stock = pd.read_csv(url)

# %%
apple_stock
# Out:
#        timestamp     open    high       low   close    volume
# 0     2024-06-07  194.650  196.94  194.1400  196.89  53103912
# 1     2024-06-06  195.685  196.50  194.1700  194.48  41181753
# 2     2024-06-05  195.400  196.90  194.8700  195.87  54156785
# 3     2024-06-04  194.635  195.32  193.0342  194.35  47471445
# 4     2024-06-03  192.900  194.99  192.5200  194.03  50080539
# ...          ...      ...     ...       ...     ...       ...
# 6185  1999-11-05   84.620   88.37   84.0000   88.31   3721500
# 6186  1999-11-04   82.060   85.37   80.6200   83.62   3384700
# 6187  1999-11-03   81.620   83.25   81.0000   81.50   2932700
# 6188  1999-11-02   78.000   81.69   77.3100   80.25   3564600
# 6189  1999-11-01   80.000   80.69   77.3700   77.62   2487300
#
# [6190 rows x 6 columns]

# %%
# Saving te stock data
apple_stock.to_csv('/content/drive/My Drive/Research Project/apple_stock.csv')
